# %% [markdown]
# # 0 - Setup (imports, semente, precisão)

# %% [markdown]
# # 1 - Dados: ler e dividir

# %% [markdown]
# # 2. Parâmetros: os `c` e `λ` das premissas

# %% [markdown]
# # 3. Foward: Fuzzyficação

# %% [markdown]
# # 4. LSE: montar `Φ` e resolver os consequentes

# %% [markdown]
# # 5. Treino: o loop híbrido

# %% [markdown]
# # 6. Avaliação: MSE/RMSE no teste

# %% [markdown]
# # 7. Gráficos: os entregáveis (a) - (e)
